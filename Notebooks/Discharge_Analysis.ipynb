# %% [markdown]
# # Identifying Treated Wastewater Discharges to Lough Neagh
#
# This notebook demonstrates the workflow used to identify treated
# wastewater discharges that ultimately flow into Lough Neagh and
# creates a map of their locations.
#
# ## Section Heading
# ## Introduction
#
# Explain:
#
# what the notebook does
# why Lough Neagh is being studied
# datasets used
#
# ### Subsection Heading
#
# ## Import Libraries

# %%
import geopandas as gpd
import pandas as pd
import matplotlib.pyplot as pl

# %% [markdown]
# ## Load Input Data
#
# Describe the datasets.

# %%
rivers = gpd.read_file(...)
discharges = gpd.read_file(...)
catchment = gpd.read_file(...)

# %% [markdown]
# ## Explore the Data

# %%
discharges.head()

# %% [markdown]
# ## Methodology
#
# The analysis identifies treated wastewater discharge points that
# drain to Lough Neagh. Spatial selection and catchment analysis are
# used to determine which discharges contribute to the Lough Neagh
# system.
#
# ## Select Relevant Discharges

# %%
selected = gpd.sjoin(

# %% [markdown]
# ## Create Map

# %% [markdown]
# fig, ax = plt.subplots(figsize=(10,10))
# selected.plot(ax=ax

# %% [markdown]
# ## Results

# %%
print(len(selected))

# %% [markdown]
# ## Conclusions
#
#
# - Treated wastewater discharges contributing to Lough Neagh were identified.
# - An output map was successfully generated.
# - The workflow can be repeated with updated datasets.
